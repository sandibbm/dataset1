# %%
import pandas as pd
df_winedataset=pd.read_csv("winedataset.csv")
df_winedataset
# Out:
#      Class  Alcohol  Malic acid   Ash  Alcalinity of ash  Magnesium  \
# 0        1    14.23        1.71  2.43               15.6        127
# 1        1    13.20        1.78  2.14               11.2        100
# 2        1    13.16        2.36  2.67               18.6        101
# 3        1    14.37        1.95  2.50               16.8        113
# 4        1    13.24        2.59  2.87               21.0        118
# ..     ...      ...         ...   ...                ...        ...
# 173      3    13.71        5.65  2.45               20.5         95
# 174      3    13.40        3.91  2.48               23.0        102
# 175      3    13.27        4.28  2.26               20.0        120
# 176      3    13.17        2.59  2.37               20.0        120
# 177      3    14.13        4.10  2.74               24.5         96
#
#      Total phenols  Flavanoids  Nonflavanoid phenols  Proanthocyanins  \
# 0             2.80        3.06                  0.28             2.29
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.heatmap(df_winedataset.isnull(),annot=True)
plt.show()

# %%
df_winedataset.columns
# Out:
# Index(['Class', 'Alcohol', 'Malic acid', 'Ash', 'Alcalinity of ash',
#        'Magnesium', 'Total phenols', 'Flavanoids', 'Nonflavanoid phenols',
#        'Proanthocyanins', 'Color intensity', 'Hue', 'diluted wines',
#        'Proline    '],
#       dtype='object')

# %%
df_winedataset.corr()
# Out:
#                          Class   Alcohol  Malic acid       Ash  \
# Class                 1.000000 -0.328222    0.437776 -0.049643
# Alcohol              -0.328222  1.000000    0.094397  0.211545
# Malic acid            0.437776  0.094397    1.000000  0.164045
# Ash                  -0.049643  0.211545    0.164045  1.000000
# Alcalinity of ash     0.517859 -0.310235    0.288500  0.443367
# Magnesium            -0.209179  0.270798   -0.054575  0.286587
# Total phenols        -0.719163  0.289101   -0.335167  0.128980
# Flavanoids           -0.847498  0.236815   -0.411007  0.115077
# Nonflavanoid phenols  0.489109 -0.155929    0.292977  0.186230
# Proanthocyanins      -0.499130  0.136698   -0.220746  0.009652
# Color intensity       0.265668  0.546364    0.248985  0.258887
# Hue                  -0.617369 -0.071747   -0.561296 -0.074667
# diluted wines        -0.788230  0.072343   -0.368710  0.003911
# Proline              -0.633717  0.643720   -0.192011  0.223626
#
# ...

# %%
df_winedataset.describe()
# Out:
#             Class     Alcohol  Malic acid         Ash  Alcalinity of ash  \
# count  178.000000  178.000000  178.000000  178.000000         178.000000
# mean     1.938202   13.000618    2.336348    2.366517          19.494944
# std      0.775035    0.811827    1.117146    0.274344           3.339564
# min      1.000000   11.030000    0.740000    1.360000          10.600000
# 25%      1.000000   12.362500    1.602500    2.210000          17.200000
# 50%      2.000000   13.050000    1.865000    2.360000          19.500000
# 75%      3.000000   13.677500    3.082500    2.557500          21.500000
# max      3.000000   14.830000    5.800000    3.230000          30.000000
#
#         Magnesium  Total phenols  Flavanoids  Nonflavanoid phenols  \
# count  178.000000     178.000000  178.000000            178.000000
# mean    99.741573       2.295112    2.029270              0.361854
# std     14.282484       0.625851    0.998859              0.124453
# ...

# %%
df_winedataset.isnull().sum()
# Out:
# Class                   0
# Alcohol                 0
# Malic acid              0
# Ash                     0
# Alcalinity of ash       0
# Magnesium               0
# Total phenols           0
# Flavanoids              0
# Nonflavanoid phenols    0
# Proanthocyanins         0
# Color intensity         0
# Hue                     0
# diluted wines           0
# Proline                 0
# dtype: int64

# %%
from scipy.stats import zscore
z_score=abs(zscore(df_winedataset))
print(df_winedataset.shape)
df_winedataset_final=df_winedataset.loc[(z_score<3).all(axis=1)]
print(df_winedataset_final.shape)
# Out:
# (178, 14)
# (168, 14)

# %%
sns.lineplot(x=df_winedataset['Alcohol'],y=df_winedataset['diluted wines'],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset['Proline    '],y=df_winedataset['diluted wines'],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Malic acid"],y=df_winedataset['diluted wines'],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Ash"],y=df_winedataset["diluted wines"],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Alcalinity of ash"],y=df_winedataset["diluted wines"],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Magnesium"],y=df_winedataset["diluted wines"],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Total phenols"],y=df_winedataset["diluted wines"],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Flavanoids"],y=df_winedataset['diluted wines'],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Nonflavanoid phenols"],y=df_winedataset['Proline    '],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Proanthocyanins"],y=df_winedataset["diluted wines"],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Color intensity"],y=df_winedataset['diluted wines'],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Hue"],y=df_winedataset["diluted wines"],data=df_winedataset)
plt.show()

# %%
sns.lineplot(x=df_winedataset["Alcalinity of ash"],y=df_winedataset['diluted wines'],data=df_winedataset)
plt.show()

# %%
sns.barplot(x=df_winedataset["Total phenols"],y=df_winedataset["diluted wines"],data=df_winedataset)
plt.show()

# %%
sns.barplot(x=df_winedataset["Flavanoids"],y=df_winedataset["diluted wines"],data=df_winedataset)
plt.show()

# %%
plt.hist(x="Total phenols",bins=10,data=df_winedataset)
plt.show()

# %%
df_winedataset.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              1.039651
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               1.098191
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.868585
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.767822
# dtype: float64

# %%
import numpy as np
for col in df_winedataset.columns:
    if df_winedataset.skew().loc[col]>0.55:
        df_winedataset[col]=np.log1p(df_winedataset[col])

# %%
df_winedataset.skew()
# Out:
# Class                   0.107431
# Alcohol                -0.051482
# Malic acid              0.529222
# Ash                    -0.176699
# Alcalinity of ash       0.213047
# Magnesium               0.605723
# Total phenols           0.086639
# Flavanoids              0.025344
# Nonflavanoid phenols    0.450151
# Proanthocyanins         0.517137
# Color intensity         0.097222
# Hue                     0.021091
# diluted wines          -0.307285
# Proline                 0.087930
# dtype: float64

# %%
import seaborn as sns
sns.pairplot(df_winedataset)
plt.show()

# %%
x=df_winedataset[["Total phenols"]]
y=df_winedataset[["diluted wines"]]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
x = sc.fit_transform(x)
x
# Out:
# array([[ 0.80899739],
#        [ 0.56864766],
#        [ 0.80899739],
#        [ 2.49144552],
#        [ 0.80899739],
#        [ 1.56209322],
#        [ 0.32829793],
#        [ 0.48853108],
#        [ 0.80899739],
#        [ 1.09741707],
#        [ 1.04934713],
#        [-0.15240153],
#        [ 0.48853108],
#        [ 1.28969686],
#        [ 1.61016317],
#        [ 0.88911397],
#        [ 0.80899739],
#        [ 1.04934713],
#        [ 1.61016317],
#        [ 0.64876424],
#        [ 1.1294637 ],
#        [ 0.18408809],
#        [ 0.5045544 ],
#        [ 0.2962513 ],
#        [ 0.37636788],
#        [ 0.53660103],
#        [ 0.88911397],
#        [ 0.16806478],
#        [ 1.04934713],
#        [ 0.56864766],
#        [ 1.1294637 ],
#        [ 0.90513729],
#        [ 0.20011141],
#        [ 1.04934713],
#        [ 0.0879482 ],
#        [ 0.64876424],
#        [ 0.48853108],
#        [ 0.24818135],
#        [ 0.16806478],
#        [ 1.1294637 ],
#        [ 1.36981344],
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 55,test_size=0.20)

# %%
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics  import r2_score
from sklearn import linear_model
max_r_score=0
for r_state in range(42,100):
    x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = r_state,test_size=0.20)
    regr = linear_model.LinearRegression()
    regr.fit(x_train,y_train)
    y_pred = regr.predict(x_test)
    r2_scr=r2_score(y_test,y_pred)
    if r2_scr>max_r_score:
        max_r_score=r2_scr
        final_r_state=r_state
print("max r2 score corresponding to ",final_r_state," is",max_r_score)
# Out:
# max r2 score corresponding to  85  is 0.705005330423297

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(linear_model.LinearRegression(),x,y,cv=10,scoring="r2").mean()
# Out:
# -2.65220644492144

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y,random_state = 56 ,test_size=0.20)
lreg= linear_model.LinearRegression()
lreg.fit(x_train,y_train)
y_pred=lreg.predict(x_test)

# %%
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
print("r2 score is : ",r2_score(y_test,y_pred))
print("RMSE is: ",np.sqrt(mean_squared_error(y_test,y_pred)))
# Out:
# r2 score is :  0.29426063111380485
# RMSE is:  0.43148565702510605

# %%
import joblib as jb
jb.dump(lreg, 'titanic_train.pkl')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-3043d0678360> in <module>
#       1 import joblib as jb
# ----> 2 jb.dump(lreg, 'titanic_train.pkl')
#
# NameError: name 'lreg' is not defined
